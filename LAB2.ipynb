# %%
import cv2

# Load an image (replace 'image.jpg' with your image file)
img = cv2.imread('C:\\Users\\saeem\\Downloads\\001.jpg', cv2.IMREAD_GRAYSCALE)  # Read as grayscale

# Find the minimum and maximum pixel values
min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(img)

print(f"Minimum pixel value: {min_val}")
print(f"Maximum pixel value: {max_val}")
# Out:
# Minimum pixel value: 18.0
# Maximum pixel value: 250.0

# %%
import cv2

# Load an image (replace 'image.jpg' with your image file)
img = cv2.imread('C:\\Users\\saeem\\Desktop\\CVLAB\\4.jpeg', cv2.IMREAD_GRAYSCALE)  # Read as grayscale

# Find the minimum and maximum pixel values
min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(img)

print(f"Minimum pixel value: {min_val}")
print(f"Maximum pixel value: {max_val}")
# Out:
# Minimum pixel value: 0.0
# Maximum pixel value: 251.0

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load an image (replace 'sample_denoise_input.jpg' with your image file)
image = cv2.imread('C:\\Users\\saeem\\Desktop\\CVLAB\\4.jpeg')

# Apply denoising
dst = cv2.fastNlMeansDenoisingColored(image, None, 11, 6, 7, 21)

# Plot the original and denoised images
plt.figure(figsize=(10, 5))
plt.subplot(121), plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB)), plt.title('Original Image')
plt.subplot(122), plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB)), plt.title('Denoised Image')
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
image = cv2.imread('C:\\Users\\saeem\\Desktop\\CVLAB\\4.jpeg')
image_rgb = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,5))
plt.subplot(1, 2, 1)
plt.imshow(image_rgb)
plt.title('Original Image(RGB)')
image_gray=cv2.cvtColor(image_rgb,cv2.COLOR_RGB2GRAY)
plt.subplot(1, 2, 2)
plt.imshow(image_gray,cmap='gray')

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load an image (replace 'image.jpg' with your image file)
image = cv2.imread('C:\\Users\\saeem\\Desktop\\CVLAB\\4.jpeg', cv2.IMREAD_GRAYSCALE)  # Read as grayscale

# Increase contrast (adjust the contrast factor as needed)
contrast_factor = 1.5  # You can experiment with different values

# Apply contrast adjustment
adjusted_image = cv2.convertScaleAbs(image, alpha=contrast_factor, beta=0)

# Display the original and adjusted images
plt.figure(figsize=(10, 5))
plt.subplot(121), plt.imshow(image, cmap='gray'), plt.title('Original Image')
plt.subplot(122), plt.imshow(adjusted_image, cmap='gray'), plt.title('Adjusted Image')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load an image (replace 'image.jpg' with your image file)
image = cv2.imread('C:\\Users\\saeem\\Desktop\\CVLAB\\4.jpeg', cv2.IMREAD_GRAYSCALE)  # Read as grayscale

# Calculate the histogram
hist, bins = np.histogram(image.ravel(), bins=256, range=[0, 256])

# Plot the histogram
plt.figure(figsize=(8, 6))
plt.bar(bins[:-1], hist, width=1, color='gray')
plt.title('Histogram of Pixel Values')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load an image (replace 'image.jpg' with your image file)
image = cv2.imread('C:\\Users\\saeem\\Desktop\\CVLAB\\4.jpeg', cv2.IMREAD_GRAYSCALE)  # Read as grayscale

# Apply histogram equalization
equalized_image = cv2.equalizeHist(image)

# Plot the original and equalized images
plt.figure(figsize=(10, 5))
plt.subplot(121), plt.imshow(image, cmap='gray'), plt.title('Original Image')
plt.subplot(122), plt.imshow(equalized_image, cmap='gray'), plt.title('Equalized Image')
plt.show()

clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
clahe_image = clahe.apply(image)

# Plot the original and CLAHE-adjusted images
plt.figure(figsize=(10, 5))
plt.subplot(121), plt.imshow(image, cmap='gray'), plt.title('Original Image')
plt.subplot(122), plt.imshow(clahe_image, cmap='gray'), plt.title('CLAHE Image')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load an image (replace 'image.jpg' with your image file)
image = cv2.imread('C:\\Users\\saeem\\Desktop\\CVLAB\\4.jpeg', cv2.IMREAD_GRAYSCALE)  # Read as grayscale

# Apply CLAHE
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
clahe_image = clahe.apply(image)

# Plot histograms
plt.figure(figsize=(12, 6))

# Original image histogram
plt.subplot(121)
plt.hist(image.ravel(), bins=256, range=[0, 256], color='blue', alpha=0.7)
plt.title('Histogram of Original Image')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')

# CLAHE-adjusted image histogram
plt.subplot(122)
plt.hist(clahe_image.ravel(), bins=256, range=[0, 256], color='green', alpha=0.7)
plt.title('Histogram of CLAHE-Adjusted Image')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
